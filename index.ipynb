# %% [markdown]
# # APIs - Cumulative Lab
#
#
# ## Introduction
#
# We've seen how the Yelp API works and how to create basic visualizations using Folium. It's time to put those skills to work in order to create a working map! Taking things a step further, you'll also independently explore how to perform pagination in order to retrieve a full results set from the Yelp API.
#
# ## Objectives
#
# You will be able to:
#
# * Practice using functions to organize your code
# * Use pagination to retrieve all results from an API query
# * Practice parsing data returned from an API query
# * Practice interpreting visualizations of a dataset
# * Create maps using Folium

# %% [markdown]
# ## Your Task: Query Yelp for All Businesses in a Category and Analyze the Results
#
# ![restaurant counter with pizza](images/restaurant_counter.jpg)
#
# Photo by <a href="https://unsplash.com/@jordanmadrid?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Jordan Madrid</a> on <a href="/s/photos/pizza-restaurant?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>

# %% [markdown]
# ### Overview
#
# You've now worked with some API calls, but we have yet to see how to retrieve a more complete dataset in a programmatic manner. In this lab, you will write a query of businesses on Yelp, then use *pagination* to retrieve all possible results for that query. Then you will create a summary of your findings, including a Folium map of the geographic locations of those businesses.
#
# ### Technical Details
#
# Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the **API limits**. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a **maximum of 50 results per request** and defaults to 20. Furthermore, any search will be limited to a **total of 1000 results**. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retrieving 50 at a time. Processes such as these are often referred to as pagination.
#
# Also, be mindful of the **API** ***rate*** **limits**. You can only make **5000 requests per day** and can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use `time.sleep(n)` to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.
#
# In this lab, you will define a search and then paginate over the results to retrieve all of the results. You'll then parse these responses as a list of dictionaries (for further exploration) and create a map using Folium to visualize the results geographically.
#
# ### Requirements
#
# #### 1. Make the Initial Request
#
# Start by filling in your API key to make the initial request to the business search API. Investigate the structure of the response you get back and start figuring out how you will extract the relevant information.
#
# #### 2. Add Pagination
#
# Using loops and functions, collect the maximum number of results for your query from the API.
#
# #### 3. Perform Exploratory Analysis
#
# Interpret visualizations related to the price range, average rating, and number of reviews for all query results.
#
# #### 4. Create a Folium Map
#
# Using latitude and longitude data, plot the query results on an interactive map.

# %% [markdown]
# ## 1. Make the Initial Request
#
# ### Querying
#
# Start by making an initial request to the Yelp API. Your search must include at least 2 parameters: **term** and **location**. For example, you might search for pizza restaurants in NYC. The term and location is up to you but make the request below.
#
# Use the `requests` library ([documentation here](https://requests.readthedocs.io/en/master/user/quickstart/#make-a-request)).
#
# You'll also need an API key from Yelp. If you haven't done this already, go to the Yelp [Manage App page](https://www.yelp.com/developers/v3/manage_app) and create a new app (after making an account if you haven't already).

# %%
pwd
# Out:
# 'C:\\Users\\Fares\\documents\\flatiron\\phase_1\\dsc-apis-lab'

# %%
# Replace None with appropriate code

# Import the requests library
import requests

# Get this from the "Manage App" page. Make sure you set them
# back to None before pushing this to GitHub, since otherwise
# your credentials will be compromised
api_key = None

# These can be whatever you want! But the solution uses "pizza"
# and "New York NY" if you want to compare your work directly
term = "pizza"
location = "New York NY"

# Set up params for request
url = "https://api.yelp.com/v3/businesses/search"
headers = {
    "Authorization": "Bearer {}".format(api_key)
}
url_params = {
    "term": term.replace(" ", "+"),
    "location": location.replace(" ", "+")
}

# Make the request using requests.get, passing in
# url, headers=headers, and params=url_params
response = requests.get(url, headers=headers, params=url_params)

# Confirm we got a 200 response
response
# Out:
# <Response [400]>

# %%
# Run this cell without changes

# Get the response body in JSON format
response_json = response.json()
# View the keys
response_json.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %% [markdown]
# ### Extracting Data
#
# Now, retrieve the value associated with the `'businesses'` key, and inspect its contents.

# %%
# Replace None with appropriate code

# Retrieve the value from response_json
businesses = response_json['businesses']

# View the first 2 records
businesses[:2]
# Out:
# [{'id': 'zj8Lq1T8KIC5zwFief15jg',
#   'alias': 'prince-street-pizza-new-york-2',
#   'name': 'Prince Street Pizza',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/PfI8oV4ct9ZJZNtUhSS8DQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#   'review_count': 4928,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72308755605564,
#    'longitude': -73.99453001177575},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '27 Prince St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['27 Prince St', 'New York, NY 10012']},
#   'phone': '+12129664100',
#   'display_phone': '(212) 966-4100',
#   'distance': 2209.3116178604555},
#  {'id': 'ysqgdbSrezXgVwER2kQWKA',
#   'alias': 'julianas-brooklyn-3',
#   'name': "Juliana's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NVoLFle5H-SHNN6piAKIYw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/julianas-brooklyn-3?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#   'review_count': 2657,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.70274718768062,
#    'longitude': -73.99343490196397},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '19 Old Fulton St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#   'phone': '+17185966700',
#   'display_phone': '(718) 596-6700',
#   'distance': 1289.8572856708206}]

# %% [markdown]
# ### Preparing Data
#
# Write a function `prepare_data` that takes in a list of dictionaries like `businesses` and returns a copy that has been prepared for analysis:
#
# 1. The `coordinates` key-value pair has been converted into two separate key-value pairs, `latitude` and `longitude`
# 2. All other key-value pairs except for `name`, `review_count`, `rating`, and `price` have been dropped
# 3. All dictionaries missing one of the relevant keys or containing null values have been dropped
#
# In other words, the final keys for each dictionary should be `name`, `review_count`, `rating`, `price`, `latitude`, and `longitude`.
#
# Complete the function in the cell below:

# %%
# Replace None with appropriate code

def prepare_data(data_list):
    """
    This function takes in a list of dictionaries and prepares it
    for analysis
    """
    
    # Make a new list to hold results
    results = []
    
    for business_data in data_list:
    
        # Make a new dictionary to hold prepared data for this business
        prepared_data = {}
        
        # Extract name, review_count, rating, and price key-value pairs
        # from business_data and add to prepared_data
        # If a key is not present in business_data, add it to prepared_data
        # with an associated value of None
        prepared_data['name'] = business_data.get('name', None)
        prepared_data['review_count'] = business_data.get('review_count', None)
        prepared_data['rating'] = business_data.get('rating', None)
        prepared_data['price'] = business_data.get('price', None)
        
    
        # Parse and add latitude and longitude columns
        coordinates =  business_data.get('coordinates', {})
        prepared_data['latitude'] = coordinates.get('latitude', None)
        prepared_data['longitude'] = coordinates.get('longitude',None)
        
        # Add to list if all values are present
        if all(prepared_data.values()):
            results.append(prepared_data)
    
    return results
    
# Test out function
prepared_businesses = prepare_data(businesses)
prepared_businesses[:5]
# Out:
# [{'name': 'Prince Street Pizza',
#   'review_count': 4928,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.72308755605564,
#   'longitude': -73.99453001177575},
#  {'name': "Juliana's",
#   'review_count': 2657,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70274718768062,
#   'longitude': -73.99343490196397},
#  {'name': 'Rubirosa',
#   'review_count': 3038,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.722766,
#   'longitude': -73.996233},
#  {'name': "L'industrie Pizzeria",
#   'review_count': 988,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.71162,
#   'longitude': -73.95783},
#  {'name': "Lombardi's Pizza",
#   'review_count': 6575,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7215934960083,
#   'longitude': -73.9955956044561}]

# %% [markdown]
# Check that your function created the correct keys:

# %%
# Run this cell without changes

assert sorted(list(prepared_businesses[0].keys())) == ['latitude', 'longitude', 'name', 'price', 'rating', 'review_count']

# %% [markdown]
# The following code will differ depending on your query, but we expect there to be 20 businesses in the original list, and potentially fewer in the prepared list (if any of them were missing data):

# %%
# Run this cell without changes
print("Original:", len(businesses))
print("Prepared:", len(prepared_businesses))
# Out:
# Original: 20
# Prepared: 19

# %% [markdown]
# Great! We will reuse this function once we have retrieved the full dataset.

# %% [markdown]
# ## 2. Add Pagination
#
# Now that you are able to extract information from one page of the response, let's figure out how to request as many pages as possible.
#
# ### Determining the Total
#
# Depending on the number of total results for your query, you will either retrieve all of the results, or just the first 1000 (if there are more than 1000 total).
#
# We can find the total number of results using the `"total"` key:

# %%
# Run this cell without changes
response_json["total"]
# Out:
# 14900

# %% [markdown]
# (This is specific to the implementation of the Yelp API. Some APIs will just tell you that there are more pages, or will tell you the number of pages total, rather than the total number of results. If you're not sure, always check the documentation.)
#
# In the cell below, assign the variable `total` to either the value shown above (if it is less than 1000), or 1000.

# %%
# Replace None with appropriate code
total = 1000

# %% [markdown]
# ### Calculating the Offsets
#
# The documentation states in the parameters section:
#
# > **Name**: `limit`, **Type:** int, **Description:** Optional. Number of business results to return. By default, it will return 20. Maximum is 50.
#
# > **Name**: `offset`, **Type:** int, **Description:** Optional. Offset the list of returned business results by this amount.
#
# So, to get the most results with the fewest API calls we want to set a limit of 50 every time. If, say, we wanted to get 210 total results, that would mean:
#
# 1. Offset of `0` (first 50 records)
# 2. Offset of `50` (second 50 records)
# 3. Offset of `100` (third 50 records)
# 4. Offset of `150` (fourth 50 records)
# 5. Offset of `200` (final 10 records)
#
# In the cell below, create a function `get_offsets` that takes in a total and returns a list of offsets for that total. You can assume that there is a limit of 50 every time.
#
# *Hint: you can use `range` ([documentation here](https://docs.python.org/3.3/library/stdtypes.html?highlight=range#range)) to do this in one line of code. Just make the returned result is a list.*

# %%
# Replace None with appropriate code
def get_offsets(total):
    """
    Get a list of offsets needed to get all pages
    of data up until the total
    """
    offsets = [i for i in range(0, total, 50)]
    return offsets

# %% [markdown]
# Check that your function works below:

# %%
range(0, total, 50)
# Out:
# range(0, 1000, 50)

# %%
# Run this cell without changes

assert get_offsets(200) == [0, 50, 100, 150]
assert get_offsets(210) == [0, 50, 100, 150, 200]

# %% [markdown]
# ### Putting It All Together
#
# Recall that the following variable has already been declared for you:

# %%
# Run this cell without changes
url_params
# Out:
# {'term': 'pizza', 'location': 'New+York+NY'}

# %% [markdown]
# We'll go ahead and also specify that the limit should be 50 every time:

# %%
# Run this cell without changes
url_params["limit"] = 50

# %% [markdown]
# In order to modify the offset, you'll need to add it to `url_params` with the key `"offset"` and whatever value is needed.
#
# In the cell below, write code that:
#
# * Creates an empty list for the full prepared dataset
# * Loops over all of the offsets from `get_offsets` and makes an API call each time with the specified offset
# * Calls `prepare_data` to get a cleaned version of the result of each API call
# * Extends the full prepared dataset list with each query's prepared dataset

# %%
# Replace None with appropriate code

# Create an empty list for the full prepared dataset
full_dataset = []

for offset in get_offsets(total):
    # Add or update the "offset" key-value pair in url_params
    url_params["offset"] = offset
    
    # Make the query and get the response
    response = requests.get(url, headers=headers, params=url_params)
    
    # Get the response body in JSON format
    response_json = response.json()
    
    # Get the list of businesses from the response_json
    businesses = response_json['businesses']
    
    # Call the prepare_data function to get a list of processed data
    prepared_businesses = prepare_data(businesses)
    
    # Extend full_dataset with this list (don't append, or you'll get
    # a list of lists instead of a flat list)
    full_dataset.extend(prepared_businesses)

# Check the length of the full dataset. It will be up to `total`,
# potentially less if there were missing values
len(full_dataset)
# Out:
# 724

# %% [markdown]
# This code may take up to a few minutes to run.
#
# If you get an error trying to get the response body in JSON format, try adding `time.sleep(1)` right after the `requests.get` line, so your code will sleep for 1 second between each API call.

# %%
response.json()
# Out:
# {'businesses': [{'id': 'PJrTtl4qM7M0VQGAZ2kDGQ',
#    'alias': 'ginos-express-pizza-middle-village',
#    'name': "Gino's of Middle Village Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BHxNM41TunNPCsc7q8AEYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ginos-express-pizza-middle-village?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 80,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7229424, 'longitude': -73.8741563},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '62-69 Dry Harbor Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Middle Village',
#     'zip_code': '11379',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['62-69 Dry Harbor Rd', 'Middle Village, NY 11379']},
#    'phone': '+17188061650',
#    'display_phone': '(718) 806-1650',
#    'distance': 9024.806773384902},
#   {'id': 'tHW3EwGwai1AiWQ6ZD-wjg',
#    'alias': 'industry-kitchen-new-york',
#    'name': 'Industry Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/c8sA-O1qWO7qY2cJg2M8gg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/industry-kitchen-new-york?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 905,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7049434740873,
#     'longitude': -74.0048825740814},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '70 South St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['70 South St', 'New York, NY 10005']},
#    'phone': '+12124879600',
#    'display_phone': '(212) 487-9600',
#    'distance': 2177.736547494339},
#   {'id': '81ATGBKh1Ke6EX_L3qHaIQ',
#    'alias': 'ferdinandos-focacceria-brooklyn-4',
#    'name': "Ferdinando's Focacceria",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/g3Lqd_6414Zh_9weDohaVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ferdinandos-focacceria-brooklyn-4?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 216,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68418116575449,
#     'longitude': -74.0018677711487},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '151 Union St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['151 Union St', 'Brooklyn, NY 11231']},
#    'phone': '+17188551545',
#    'display_phone': '(718) 855-1545',
#    'distance': 3175.175072604963},
#   {'id': 'Vs8kQ4R381y27AH018gLpg',
#    'alias': 'supper-new-york',
#    'name': 'Supper',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VgYreViVbDel2zylxtNEXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/supper-new-york?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 1475,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72290786539601,
#     'longitude': -73.98520720537888},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '156 E 2nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['156 E 2nd St', 'New York, NY 10009']},
#    'phone': '+12124777600',
#    'display_phone': '(212) 477-7600',
#    'distance': 1842.5875968252572},
#   {'id': 'xJIVwYBIEppz4CJ19wcuvA',
#    'alias': 'bella-donna-pizzeria-maspeth',
#    'name': 'Bella Donna Pizzeria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UXKp85OI13ksjKmVMM8wcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bella-donna-pizzeria-maspeth?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 30,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71339588236523,
#     'longitude': -73.91075417663387},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '6091 54th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Maspeth',
#     'zip_code': '11378',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6091 54th St', 'Maspeth, NY 11378']},
#    'phone': '+17184971744',
#    'display_phone': '(718) 497-1744',
#    'distance': 5812.029016528562},
#   {'id': 'WHQpLvxkCK_BMtF8pIShnQ',
#    'alias': 'carroll-place-new-york',
#    'name': 'Carroll Place',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/InhWyr6n7nUIBgdJ6sJGNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carroll-place-new-york?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 1266,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7287, 'longitude': -73.99971},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '157 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['157 Bleecker St', 'New York, NY 10012']},
#    'phone': '+12122601700',
#    'display_phone': '(212) 260-1700',
#    'distance': 2972.197073390781},
#   {'id': 'NIGRsA3aRFQUEtxl63IAMQ',
#    'alias': 'the-big-red-tomato-fort-lee',
#    'name': 'The Big Red Tomato',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NsemrIwW69DxJK-0i7K0Ew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-big-red-tomato-fort-lee?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 293,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.8395, 'longitude': -73.98192},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1205 Anderson Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Fort Lee',
#     'zip_code': '07024',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1205 Anderson Ave', 'Fort Lee, NJ 07024']},
#    'phone': '+12012246500',
#    'display_phone': '(201) 224-6500',
#    'distance': 14731.658365320163},
#   {'id': '88T5ILS9juanUPFlcY8UcA',
#    'alias': 'ipizzany-new-york-10',
#    'name': 'IPizzaNY',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/elXDRMF4Z_8-F-8-HsHLFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ipizzany-new-york-10?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 4,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.744715, 'longitude': -73.976175},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '621 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['621 2nd Ave', 'New York, NY 10016']},
#    'phone': '+16465967071',
#    'display_phone': '(646) 596-7071',
#    'distance': 4203.859770687415},
#   {'id': 'nU9lEZpCnR7V_M14xV19NQ',
#    'alias': 'armandos-pizza-brooklyn-4',
#    'name': "Armando's Pizza",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gXToh15Tm5ocLzbjo9PXlA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/armandos-pizza-brooklyn-4?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 83,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.645742, 'longitude': -73.9027409},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1413 Rockaway Pkwy',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11236',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1413 Rockaway Pkwy', 'Brooklyn, NY 11236']},
#    'phone': '+17182579723',
#    'display_phone': '(718) 257-9723',
#    'distance': 9387.148982880297},
#   {'id': 'e5VNqnVitx8OrnINaMMCsA',
#    'alias': 'fedoroffs-roast-pork-brooklyn',
#    'name': "Fedoroff's Roast Pork",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MxKSNDcK-qwIpeKJEp4J-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fedoroffs-roast-pork-brooklyn?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 367,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7189526, 'longitude': -73.9555245},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '178 N 10th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['178 N 10th St', 'Brooklyn, NY 11211']},
#    'phone': '+13473842222',
#    'display_phone': '(347) 384-2222',
#    'distance': 2398.0298766720025},
#   {'id': 'GyN4Kl0vFwziRN-h-Ow7ig',
#    'alias': 'saint-pizza-new-york',
#    'name': 'Saint Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6gTOBJcMgeW_-oPp08WEMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saint-pizza-new-york?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 4,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72905715251202,
#     'longitude': -73.97811846649704},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '223 Avenue B',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['223 Avenue B', 'New York, NY 10009']},
#    'phone': '+16463988250',
#    'display_phone': '(646) 398-8250',
#    'distance': 2456.770265031936},
#   {'id': 'D4vcEbaq1DjFG6FVk26ReQ',
#    'alias': 'la-amistad-pizzeria-and-grill-new-york',
#    'name': 'La Amistad Pizzeria & Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0gUNvGEyET9khWd8wTKO5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-amistad-pizzeria-and-grill-new-york?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 26,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.79098, 'longitude': -73.94241},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '2067 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10029',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2067 2nd Ave', 'New York, NY 10029']},
#    'phone': '+12122560129',
#    'display_phone': '(212) 256-0129',
#    'distance': 9845.549236098337},
#   {'id': 'dc3hkLkAqCSxDWQzrx-g9A',
#    'alias': 'quality-italian-new-york',
#    'name': 'Quality Italian',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7JK95Qmi9lKwvI7ags6fVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/quality-italian-new-york?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 1365,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7644044527436,
#     'longitude': -73.9767805051616},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '57 W 57th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['57 W 57th St', 'New York, NY 10019']},
#    'phone': '+12123901111',
#    'display_phone': '(212) 390-1111',
#    'distance': 6388.77363660067},
#   {'id': 'j9TdOBSQ1LRw8v3hW5fObQ',
#    'alias': 'pies-n-thighs-brooklyn',
#    'name': 'Pies-n-Thighs',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/N9diUzihPiuCXe1sngxq_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pies-n-thighs-brooklyn?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 3182,
#    'categories': [{'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.711191, 'longitude': -73.961424},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '166 S 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['166 S 4th St', 'Brooklyn, NY 11211']},
#    'phone': '+13475296090',
#    'display_phone': '(347) 529-6090',
#    'distance': 1568.815133057466},
#   {'id': '14CZLOKOX7GJqbTaUt5HpQ',
#    'alias': 'rizzos-bakery-jersey-city',
#    'name': "Rizzo's Bakery",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SACWEMaP9FnSx4D5OYQXQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rizzos-bakery-jersey-city?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 123,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74173, 'longitude': -74.052106},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '208 Central Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07307',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['208 Central Ave', 'Jersey City, NJ 07307']},
#    'phone': '+12016537248',
#    'display_phone': '(201) 653-7248',
#    'distance': 7258.924873900162},
#   {'id': 'YuOG9xuF9qze3bUQFXXD4g',
#    'alias': 'jersey-pizza-boys-woodbridge-township',
#    'name': 'Jersey Pizza Boys',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/U85a8sXAqzpcTYuFZx593Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jersey-pizza-boys-woodbridge-township?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 54,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.57677540392761,
#     'longitude': -74.27628893405199},
#    'transactions': [],
#    'location': {'address1': '147 Avenel St',
#     'address2': '',
#     'address3': None,
#     'city': 'Woodbridge Township',
#     'zip_code': '07001',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['147 Avenel St', 'Woodbridge Township, NJ 07001']},
#    'phone': '+17326343983',
#    'display_phone': '(732) 634-3983',
#    'distance': 28948.159480540588},
#   {'id': 'U5hCNNyJmb7f3dmC1HTzSQ',
#    'alias': 'juniors-restaurant-new-york-9',
#    'name': "Junior's Restaurant",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SnBx8QkJfCb6-4mcQYjkQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/juniors-restaurant-new-york-9?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 5736,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75754728725579,
#     'longitude': -73.98608001118411},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1515 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1515 Broadway', 'New York, NY 10036']},
#    'phone': '+12123022000',
#    'display_phone': '(212) 302-2000',
#    'distance': 5652.989837985306},
#   {'id': '0rBGHaXh9On9qankZZU0QQ',
#    'alias': 'dozzino-hoboken',
#    'name': 'Dozzino',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FWMHSmg99A728eqW_sZxIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dozzino-hoboken?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 337,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.74455, 'longitude': -74.03579},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '534 Adams St',
#     'address2': '',
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['534 Adams St', 'Hoboken, NJ 07030']},
#    'phone': '+12016566561',
#    'display_phone': '(201) 656-6561',
#    'distance': 6337.672675020043},
#   {'id': 'VF3wSCRC3mE6JpBQPQXELA',
#    'alias': 'parm-new-york',
#    'name': 'Parm',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3NVz_h6LtzLyEgl52AFfYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/parm-new-york?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 877,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72303, 'longitude': -73.99567},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '248 Mulberry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['248 Mulberry St', 'New York, NY 10012']},
#    'phone': '+12129937189',
#    'display_phone': '(212) 993-7189',
#    'distance': 2263.44281967944},
#   {'id': '_w_bvxnA_ARuQbu9K-lTAw',
#    'alias': 'lennys-pizza-sunnyside',
#    'name': "Lenny's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ILA15Z-EIdnHy5AYY16Baw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lennys-pizza-sunnyside?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 146,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.74145, 'longitude': -73.92022},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '44-08 Greenpoint Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Sunnyside',
#     'zip_code': '11104',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['44-08 Greenpoint Ave', 'Sunnyside, NY 11104']},
#    'phone': '+17187868100',
#    'display_phone': '(718) 786-8100',
#    'distance': 6260.762505419292},
#   {'id': '9GPRbrLHvPmLScQVw7L3KA',
#    'alias': 'donatos-restaurant-and-pizza-woodside',
#    'name': "Donato's Restaurant and Pizza",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TJeonHE3XIjTiupkjlfSlg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/donatos-restaurant-and-pizza-woodside?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 199,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.748620275297355,
#     'longitude': -73.91300763769813},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '50-22 39th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['50-22 39th Ave', 'Woodside, NY 11377']},
#    'phone': '+17185074591',
#    'display_phone': '(718) 507-4591',
#    'distance': 7248.431748404498},
#   {'id': 'SSb_9z0rTGKnHD9DWP-F_A',
#    'alias': 'velma-ridgewood',
#    'name': 'Velma',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cdeHkEi9Y6IE4ilbVCaWlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/velma-ridgewood?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 13,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70424540007157, 'longitude': -73.9104028},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '584 Seneca Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['584 Seneca Ave', 'Ridgewood, NY 11385']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5806.016152688211},
#   {'id': 'KMA2hqRAcjHa3QMJ5ynz0g',
#    'alias': 'ipizzany-new-york-8',
#    'name': 'iPizzaNY',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YdmrQHzgQg3qopqfvfLynA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ipizzany-new-york-8?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 10,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76077, 'longitude': -73.99071},
#    'transactions': [],
#    'location': {'address1': '656 9th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['656 9th Ave', 'New York, NY 10036']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6057.47780044872},
#   {'id': 'PkmO99zR-93y5uWZ_U1sSg',
#    'alias': 'la-gondola-pizzeria-ramsey',
#    'name': 'La Gondola Pizzeria ',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NWikSulzKo3KUkrmZn736A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-gondola-pizzeria-ramsey?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 224,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.07253930513272,
#     'longitude': -74.13805680930825},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1300 Rt 17 N',
#     'address2': '',
#     'address3': '',
#     'city': 'Ramsey',
#     'zip_code': '07446',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1300 Rt 17 N', 'Ramsey, NJ 07446']},
#    'phone': '+12018258990',
#    'display_phone': '(201) 825-8990',
#    'distance': 42786.06946679056},
#   {'id': 'Xw9YtynzF6G5Zyx-VpG5hg',
#    'alias': 'amuni-brooklyn',
#    'name': 'Amuni',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8F7RpWZXznqhoEmzjpDCnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amuni-brooklyn?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 66,
#    'categories': [{'alias': 'sicilian', 'title': 'Sicilian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.633001, 'longitude': -74.026833},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '7217 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7217 3rd Ave', 'Brooklyn, NY 11209']},
#    'phone': '+17188337833',
#    'display_phone': '(718) 833-7833',
#    'distance': 9154.196943289024},
#   {'id': '6G0urbBDz_CnYnGXApgUcw',
#    'alias': 'boutros-brooklyn',
#    'name': 'Boutros',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TftwL8OV7OJ170VZH3LUCg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boutros-brooklyn?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 191,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6901481293837,
#     'longitude': -73.9935445412993},
#    'transactions': ['pickup'],
#    'price': '$$$',
#    'location': {'address1': '185 Atlantic Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['185 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+17184030055',
#    'display_phone': '(718) 403-0055',
#    'distance': 2228.6771619537203},
#   {'id': 'zT4j8aDmKnOAEa3iXPoUlw',
#    'alias': 'da-mario-pizzeria-rutherford',
#    'name': 'Da Mario Pizzeria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kaTHbKprZBMlVN4SjlBfFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/da-mario-pizzeria-rutherford?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 69,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.8278, 'longitude': -74.10236},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '25 Park Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Rutherford',
#     'zip_code': '07070',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['25 Park Ave', 'Rutherford, NJ 07070']},
#    'phone': '+12019355817',
#    'display_phone': '(201) 935-5817',
#    'distance': 16980.646885657334},
#   {'id': 'ThQYtK9Q8WiLV-nfS4W50w',
#    'alias': 'steve-s-tuxedo-tuxedo-park',
#    'name': 'Steve’s Tuxedo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/L52y-ScYXeYz-EuiRUo5-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/steve-s-tuxedo-tuxedo-park?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 146,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.188282, 'longitude': -74.183514},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '156 NY-17',
#     'address2': '',
#     'address3': None,
#     'city': 'Tuxedo Park',
#     'zip_code': '10987',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['156 NY-17', 'Tuxedo Park, NY 10987']},
#    'phone': '+18459153022',
#    'display_phone': '(845) 915-3022',
#    'distance': 56202.46707992627},
#   {'id': 'BCPmwgqOPj6d82OSIyqWaw',
#    'alias': 'armandos-pizza-brooklyn',
#    'name': 'Armandos Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LSw_DuLEA1wsl_M1iK0KYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/armandos-pizza-brooklyn?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 44,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.646676, 'longitude': -73.883467},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1366 Pennsylvania Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11239',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1366 Pennsylvania Ave', 'Brooklyn, NY 11239']},
#    'phone': '+17186428253',
#    'display_phone': '(718) 642-8253',
#    'distance': 10493.728601875433},
#   {'id': 'HhTHaQT2-34PXPUyGekBTQ',
#    'alias': 'cecilias-pizzeria-brooklyn',
#    'name': "Cecilia's Pizzeria",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PY_SiPPxgqw9BoLLRse91Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cecilias-pizzeria-brooklyn?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 4,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.630189, 'longitude': -73.928527},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1716 Utica Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11234',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1716 Utica Ave', 'Brooklyn, NY 11234']},
#    'phone': '+17184847495',
#    'display_phone': '(718) 484-7495',
#    'distance': 9540.912206507654},
#   {'id': 'uNC4geWdSHKLIXJFAUyGCg',
#    'alias': 'phillies-pizza-and-restaurant-middle-village',
#    'name': 'Phillies Pizza & Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2hVBDe0XSCFGlvEkz0WQfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/phillies-pizza-and-restaurant-middle-village?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 205,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.72193, 'longitude': -73.8853199},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '7402 Eliot Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Middle Village',
#     'zip_code': '11379',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7402 Eliot Ave', 'Middle Village, NY 11379']},
#    'phone': '+17183971340',
#    'display_phone': '(718) 397-1340',
#    'distance': 8082.426629521173},
#   {'id': 'eMCbaRTqVF9cdOPmGnLn_g',
#    'alias': 'garden-pizza-fairview',
#    'name': 'Garden Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SDOCOL8MRT1HZgzSzGs8tQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/garden-pizza-fairview?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 120,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.81648, 'longitude': -74.00288},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '153 Bergen Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Fairview',
#     'zip_code': '07022',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['153 Bergen Blvd', 'Fairview, NJ 07022']},
#    'phone': '+12019418510',
#    'display_phone': '(201) 941-8510',
#    'distance': 12310.612888203019},
#   {'id': '1PBlkYAEFhc0cpqNNvlkWg',
#    'alias': 'the-ear-inn-new-york',
#    'name': 'The Ear Inn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cXMemGjeZL1mpsoIDu6dfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ear-inn-new-york?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 428,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.725925, 'longitude': -74.009489},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '326 Spring St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['326 Spring St', 'New York, NY 10013']},
#    'phone': '+12122269060',
#    'display_phone': '(212) 226-9060',
#    'distance': 3310.724706676534},
#   {'id': 'psgUOYnxsQgC9JKRZcOCxg',
#    'alias': 'una-pizza-napoletana-new-york-2',
#    'name': 'Una Pizza Napoletana',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/d9xzd9XDJUg8a_YsXNUVgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/una-pizza-napoletana-new-york-2?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 156,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72175, 'longitude': -73.98864},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '175 Orchard St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['175 Orchard St', 'New York, NY 10002']},
#    'phone': '+16464764457',
#    'display_phone': '(646) 476-4457',
#    'distance': 1821.4779561157372},
#   {'id': 'U0qnUmFtGdiPm6I0x-Jd7Q',
#    'alias': 'little-italy-pizza-new-york-40',
#    'name': 'Little Italy Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/t59mfa_MnS1st4ynZ0fE0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-italy-pizza-new-york-40?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 44,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75975, 'longitude': -73.98372},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '167 W 48th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['167 W 48th St', 'New York, NY 10036']},
#    'phone': '+16463602346',
#    'display_phone': '(646) 360-2346',
#    'distance': 5884.675933855929},
#   {'id': 'KW5ScWQd16gJ9yLf4pKDvQ',
#    'alias': 'fatta-mano-brooklyn',
#    'name': 'Fatta Mano',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AN9DCLWkTAVV-dN9MV-U9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fatta-mano-brooklyn?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 46,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.62417475787952,
#     'longitude': -74.0305181171787},
#    'transactions': ['pickup', 'restaurant_reservation'],
#    'location': {'address1': '8501 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8501 3rd Ave', 'Brooklyn, NY 11209']},
#    'phone': '+17189252667',
#    'display_phone': '(718) 925-2667',
#    'distance': 10174.378227832161},
#   {'id': 'UrlJnjVMYF1GpKhKslobrw',
#    'alias': 'sabatino-s-maplewood',
#    'name': 'Sabatino’s',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/16-Zc3tZs1mrQcp__JnCnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sabatino-s-maplewood?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 74,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7340131503814,
#     'longitude': -74.2696372661238},
#    'transactions': ['delivery'],
#    'location': {'address1': '513 Valley St',
#     'address2': '',
#     'address3': None,
#     'city': 'Maplewood',
#     'zip_code': '07040',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['513 Valley St', 'Maplewood, NJ 07040']},
#    'phone': '+19733279977',
#    'display_phone': '(973) 327-9977',
#    'distance': 24661.494666024857},
#   {'id': 'kDJbzzmCEjFbyDQ-lSygvw',
#    'alias': 'fresh-salt-new-york',
#    'name': 'Fresh Salt',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rgUapzpbX-dSGoFywGkdrA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fresh-salt-new-york?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 426,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70707, 'longitude': -74.00244},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '146 Beekman St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['146 Beekman St', 'New York, NY 10038']},
#    'phone': '+12129620053',
#    'display_phone': '(212) 962-0053',
#    'distance': 1960.585190529521},
#   {'id': '6TCMYUyT45aj-89fYJOiyw',
#    'alias': 'porta-jersey-city-2',
#    'name': 'Porta',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HIfxfZ-xoMUke-Q9-MJmHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/porta-jersey-city-2?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 1226,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7200699, 'longitude': -74.0437622},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '135 Newark Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['135 Newark Ave', 'Jersey City, NJ 07302']},
#    'phone': '+12015445199',
#    'display_phone': '(201) 544-5199',
#    'distance': 5633.191474998054},
#   {'id': 'GBNHyFTBm-dyVm_n05SCCA',
#    'alias': 'adrians-jersey-pizza-wood-ridge-2',
#    'name': "Adrian's Jersey Pizza",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Qf7UC39whilMxxUAaVHcOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/adrians-jersey-pizza-wood-ridge-2?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 241,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.846881, 'longitude': -74.082494},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '200 Hackensack St',
#     'address2': '',
#     'address3': '',
#     'city': 'Wood-Ridge',
#     'zip_code': '07075',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['200 Hackensack St', 'Wood-Ridge, NJ 07075']},
#    'phone': '+12017288600',
#    'display_phone': '(201) 728-8600',
#    'distance': 17823.40706291758},
#   {'id': 'gTEoEsssfbjl76Opf5bP9g',
#    'alias': 'l-amico-nyc-new-york',
#    'name': "L'Amico NYC",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aDjdvg90J54et6UCdSPmNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-amico-nyc-new-york?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 560,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7469265, 'longitude': -73.99009231127866},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '849 6th Ave',
#     'address2': '',
#     'address3': 'Eventi Hotel',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['849 6th Ave', 'Eventi Hotel', 'New York, NY 10001']},
#    'phone': '+12122014065',
#    'display_phone': '(212) 201-4065',
#    'distance': 4536.155191054386},
#   {'id': 'oIHAY_PZ5PF95D8MF5DFKQ',
#    'alias': 'crown-heights-pizza-brooklyn',
#    'name': 'Crown Heights Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/obF58AmhxlJ6oqgknuqwjQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crown-heights-pizza-brooklyn?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 66,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.671722, 'longitude': -73.9580069},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '563 Lincoln Pl',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['563 Lincoln Pl', 'Brooklyn, NY 11238']},
#    'phone': '+17186764477',
#    'display_phone': '(718) 676-4477',
#    'distance': 4310.8477598414875},
#   {'id': '1To57srDy-cVko5QWGcogA',
#    'alias': 'sacco-pizza-new-york',
#    'name': 'Sacco Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/b1_x1cbMhxdi8mkdRkqigQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sacco-pizza-new-york?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 449,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7662658691406,
#     'longitude': -73.9872665405273},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '819 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['819 9th Ave', 'New York, NY 10019']},
#    'phone': '+12125827765',
#    'display_phone': '(212) 582-7765',
#    'distance': 6624.636851925787},
#   {'id': '9T72WRao1s5IClSuyx2xcQ',
#    'alias': 'ciro-s-by-the-beach-rockaway-park-2',
#    'name': 'Ciro’s By The Beach',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ktkDnk1i1jn2YOlyP7BTog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ciro-s-by-the-beach-rockaway-park-2?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 5,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.57914, 'longitude': -73.83702},
#    'transactions': [],
#    'location': {'address1': '171 Beach 116th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Rockaway Park',
#     'zip_code': '11694',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['171 Beach 116th St', 'Rockaway Park, NY 11694']},
#    'phone': '+17186346800',
#    'display_phone': '(718) 634-6800',
#    'distance': 18597.899986940898},
#   {'id': 'u-MUL83NUy2gsbV80WZnAA',
#    'alias': 'the-marshal-new-york',
#    'name': 'The Marshal',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uT3Jzx1fsEnvvpscviMtQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-marshal-new-york?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 835,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.761225, 'longitude': -73.993968},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '628 10th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['628 10th Ave', 'New York, NY 10036']},
#    'phone': '+12125826300',
#    'display_phone': '(212) 582-6300',
#    'distance': 6160.999876967539},
#   {'id': 'g-Wk89t79HQqhXM06sv9Ug',
#    'alias': 'la-nova-brick-oven-pizza-brooklyn',
#    'name': 'La Nova Brick Oven Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iDgLqhYR01igzlL6qulO8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-nova-brick-oven-pizza-brooklyn?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 17,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68476, 'longitude': -73.914},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1636 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11207',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1636 Broadway', 'Brooklyn, NY 11207']},
#    'phone': '+13474258391',
#    'display_phone': '(347) 425-8391',
#    'distance': 6025.314737631462},
#   {'id': 'vmLSMUdkNNkcdyuu2teAYw',
#    'alias': 'taste-of-tuscany-hackensack',
#    'name': 'Taste of Tuscany',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7lH2S7HgnHUxscCIbPNz8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taste-of-tuscany-hackensack?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 101,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8568353549895,
#     'longitude': -74.0434074881405},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '500 S River St',
#     'address2': None,
#     'address3': None,
#     'city': 'Hackensack',
#     'zip_code': '07601',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['500 S River St', 'Hackensack, NJ 07601']},
#    'phone': '+12016417500',
#    'display_phone': '(201) 641-7500',
#    'distance': 17518.731625235258},
#   {'id': 'aFHVYMXuqLgy8iKT4p9MqA',
#    'alias': 'mama-rosa-cucina-pizzeria-bayonne',
#    'name': 'Mama Rosa Cucina Pizzeria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sjnwpWAKPimgGM1XsC1HZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mama-rosa-cucina-pizzeria-bayonne?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 78,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.648513, 'longitude': -74.138297},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '53 Kennedy Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Bayonne',
#     'zip_code': '07002',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['53 Kennedy Blvd', 'Bayonne, NJ 07002']},
#    'phone': '+12018230500',
#    'display_phone': '(201) 823-0500',
#    'distance': 14909.497499817278},
#   {'id': 'W7JHjVUbTkh8J8x58ArH0w',
#    'alias': 'pepe-joes-brick-oven-pizza-bronx',
#    'name': "Pepe Joe's Brick Oven Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/spPqWUAbr5kekiTKp3TbgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pepe-joes-brick-oven-pizza-bronx?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 15,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.820786, 'longitude': -73.917273},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '722 Courtlandt Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Bronx',
#     'zip_code': '10451',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['722 Courtlandt Ave', 'Bronx, NY 10451']},
#    'phone': '+17185854922',
#    'display_phone': '(718) 585-4922',
#    'distance': 13687.073251600706},
#   {'id': 'qhvFdRNypRCdSg_inFe-2A',
#    'alias': 'nicks-pizza-forest-hills-forest-hills-2',
#    'name': "Nick's Pizza - Forest Hills",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1uWGNi2LcjEBTVJ5S6RpXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nicks-pizza-forest-hills-forest-hills-2?adjust_creative=Jcn3SWjPPGUonoYb1SPGDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Jcn3SWjPPGUonoYb1SPGDw',
#    'review_count': 969,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71797254115706,
#     'longitude': -73.84048067055303},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '108-26 Ascan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['108-26 Ascan Ave', 'Forest Hills, NY 11375']},
#    'phone': '+17182631126',
#    'display_phone': '(718) 263-1126',
#    'distance': 11754.587297648826}],
#  'total': 15600,
#  'region': {'center': {'longitude': -73.97918701171875,
#    'latitude': 40.706977710584276}}}

# %% [markdown]
# ## 3. Perform Exploratory Analysis
#
# Take the businesses from the previous question and do an initial exploratory analysis. We have provided some plots for you to interpret:

# %%
# Run this cell without changes
from collections import Counter
import matplotlib.pyplot as plt
# %matplotlib inline

fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(16, 5))

# Plot distribution of number of reviews
all_review_counts = [x["review_count"] for x in full_dataset]
ax1.hist(all_review_counts)
ax1.set_title("Review Count Distribution")
ax1.set_xlabel("Number of Reviews")
ax1.set_ylabel("Number of Businesses")

# Plot rating distribution
all_ratings = [x["rating"] for x in full_dataset]
rating_counter = Counter(all_ratings)
rating_keys = sorted(rating_counter.keys())
ax2.bar(rating_keys, [rating_counter[key] for key in rating_keys])
ax2.set_title("Rating Distribution")
ax2.set_xlabel("Rating")
ax2.set_ylabel("Number of Businesses")

# Plot price distribution
all_prices = [x["price"].replace("$", r"\$") for x in full_dataset]
price_counter = Counter(all_prices)
price_keys = sorted(price_counter.keys())
ax3.bar(price_keys, [price_counter[key] for key in price_keys])
ax3.set_title("Price Distribution")
ax3.set_xlabel("Price Category")
ax3.set_ylabel("Number of Businesses");

# %% [markdown]
# Describe the distributions displayed above and interpret them in the context of your query. (Your answer may differ from the solution branch depending on your query.)

# %%
# Replace None with appropriate text
"""
most buisnessses have less than 2,500 reviews. with a couple outliers in the 15000 range, which might be an error. 

Rating is pretty evenlly distributed, with slight right left skew. average about 4.0

price is mainly in the $ and $$ catyeogry with few in the $$$ and an outliar or few in the $$$$ cateogry, 

"""
# Out:
# '\nmost buisnessses have less than 2,500 reviews. with a couple outliers in the 15000 range, which might be an error. \n\nRating is pretty evenlly distributed, with slight right left skew. average about 4.0\n\nprice is mainly in the $ and $$ catyeogry with few in the $$$ and an outliar or few in the $$$$ cateogry, \n\n'

# %% [markdown]
# In the cell below, we also plot the rating distributions by price. In this setup, a price of one dollar sign is "lower price" and everything else is "higher price".

# %%
# Run this cell without changes

higher_price = []
lower_price = []
for row in full_dataset:
    if row["price"] == "$":
        lower_price.append(row["rating"])
    else:
        higher_price.append(row["rating"])
        
fig, ax = plt.subplots()

ax.hist([higher_price, lower_price], label=["higher price", "lower price"], density=True)

ax.legend();

# %% [markdown]
# Is a higher price associated with a higher rating? (No need for any additional math/statistics, just interpret what you see in the plot.)

# %%
# Replace None with appropriate text
"""
higher price is slightly associated with a higher rating, as most in the 5star, 4.5, and 4 star ccategory are higher priced. This reverses when entering the 3.5 and lower range in which more lower priced buisnesses are the majority.
"""
# Out:
# '\nhigher price is slightly associated with a higher rating, as most in the 5star, 4.5, and 4 star ccategory are higher priced. This reverses when entering the 3.5 and lower range in which more lower priced buisnesses are the majority.\n'

# %% [markdown]
# Finally, let's look at ratings vs. review counts:

# %%
# Run this cell without changes
fig, ax = plt.subplots(figsize=(16,5))

ax.scatter(all_review_counts, all_ratings, alpha=0.2)
ax.set_xlabel("Number of Reviews")
ax.set_ylabel("Rating")
# "zoom in" to a subset of review counts
ax.set_xlim(left=0, right=1000);

# %% [markdown]
# Is a higher number of reviews associated with a higher rating?

# %%
# Replace None with appropriate text
"""
higher number of reviews equates to more likely to gravitate towards the average of 4 stars. those in 5, 2.5, and 3star are have very few reviews. 

"""
# Out:
# '\nhigher number of reviews equates to more likely to gravitate towards the average of 4 stars. those in 5, 2.5, and 3star are have very few reviews. \n\n'

# %% [markdown]
# ## 4. Create a Folium Map
#
# Make a map using Folium of the businesses you retrieved. Be sure to also add popups to the markers giving some basic information such as name, rating and price.
#
# You can center the map around the latitude and longitude of the first item in `full_dataset`.

# %%
# Import the library
import folium

# %%
# Set up center latitude and longitude
center_lat = 40.75
center_long = -73.95

# Initialize map with center lat and long
yelp_map = folium.Map([center_lat, center_long], zoom_start=13)

# Adjust this limit to see more or fewer businesses
limit=100

# %%
yelp_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Replace None with appropriate code

for business in full_dataset[:limit]:
    # Extract information about business
    lat = business['latitude']
    long = business['longitude']
    name = business['name']
    rating = business['rating']
    price = business['price']
    details = "{}\nPrice: {} Rating:{}".format(name,price,rating)
    
    # Create popup with relevant details
    popup = folium.Popup(details, parse_html=True)
    
    # Create marker with relevant lat/long and popup
    marker = folium.Marker(location=[lat, long], popup=popup)
    
    marker.add_to(yelp_map)
    
yelp_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
business['longitude']
# Out:
# -73.9207081

# %%
full_dataset
# Out:
# [{'name': 'Prince Street Pizza',
#   'review_count': 4928,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.72308755605564,
#   'longitude': -73.99453001177575},
#  {'name': "Juliana's",
#   'review_count': 2657,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70274718768062,
#   'longitude': -73.99343490196397},
#  {'name': 'Rubirosa',
#   'review_count': 3038,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.722766,
#   'longitude': -73.996233},
#  {'name': "L'industrie Pizzeria",
#   'review_count': 988,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.71162,
#   'longitude': -73.95783},
#  {'name': "Lombardi's Pizza",
#   'review_count': 6575,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7215934960083,
#   'longitude': -73.9955956044561},
#  {'name': "Joe's Pizza",
#   'review_count': 3020,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73060076,
#   'longitude': -74.00215997},
#  {'name': "Joe's Pizza",
#   'review_count': 1926,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7547,
#   'longitude': -73.98696},
#  {'name': "Rizzo's Fine Pizza",
#   'review_count': 661,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.76337,
#   'longitude': -73.915124},
#  {'name': "John's of Bleecker Street",
#   'review_count': 2571,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73158,
#   'longitude': -74.00332},
#  {'name': 'Gelso & Grand',
#   'review_count': 1412,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.71958,
#   'longitude': -73.99734},
#  {'name': 'Olio e Più',
#   'review_count': 4535,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.733798036104304,
#   'longitude': -73.99977392649927},
#  {'name': "Grimaldi's Pizzeria",
#   'review_count': 4937,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7026459,
#   'longitude': -73.9932413},
#  {'name': 'Piz-zetta',
#   'review_count': 342,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.69116658201196,
#   'longitude': -73.99065911521895},
#  {'name': "Joe's Pizza",
#   'review_count': 445,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7168952,
#   'longitude': -73.95892996733771},
#  {'name': 'Lucali',
#   'review_count': 1966,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.681840746711224,
#   'longitude': -74.0003327},
#  {'name': "Scarr's Pizza",
#   'review_count': 776,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7157238,
#   'longitude': -73.99161149999999},
#  {'name': 'Bleecker Street Pizza',
#   'review_count': 2845,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7320627016512,
#   'longitude': -74.0036552270137},
#  {'name': 'Nolita Pizza',
#   'review_count': 204,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7208883,
#   'longitude': -73.9962404},
#  {'name': "Joe's Pizza",
#   'review_count': 471,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7101297729083,
#   'longitude': -74.0077206864953},
#  {'name': 'Front Street Pizza',
#   'review_count': 457,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.70244,
#   'longitude': -73.98943},
#  {'name': "Roberta's",
#   'review_count': 3284,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70493,
#   'longitude': -73.93399},
#  {'name': 'NY Pizza Suprema',
#   'review_count': 2471,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7502059936523,
#   'longitude': -73.9953231811523},
#  {'name': 'Norma',
#   'review_count': 610,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.743553,
#   'longitude': -73.980026},
#  {'name': 'Cuts & Slices',
#   'review_count': 337,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6854737,
#   'longitude': -73.9203186},
#  {'name': 'Song E Napule',
#   'review_count': 702,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72813,
#   'longitude': -74.00188},
#  {'name': "Paulie Gee's",
#   'review_count': 1347,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.729546,
#   'longitude': -73.958568},
#  {'name': 'Barano',
#   'review_count': 319,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.710372,
#   'longitude': -73.96794},
#  {'name': "Mancini's Wood-Fired Pizza",
#   'review_count': 148,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.62207,
#   'longitude': -74.02591},
#  {'name': "Dellarocco's Brick Oven Pizza",
#   'review_count': 350,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6950309,
#   'longitude': -73.9961252},
#  {'name': '99 Cent Fresh Pizza',
#   'review_count': 694,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.76458,
#   'longitude': -73.98247},
#  {'name': "Ace's Pizza",
#   'review_count': 144,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.71505,
#   'longitude': -73.958365},
#  {'name': "Paulie Gee's Slice Shop",
#   'review_count': 338,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.72836,
#   'longitude': -73.9572},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 4194,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7321124557704,
#   'longitude': -73.9839056828882},
#  {'name': 'Sottocasa Pizzeria',
#   'review_count': 717,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.688285,
#   'longitude': -73.989006},
#  {'name': 'Marinara Pizza',
#   'review_count': 332,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7826,
#   'longitude': -73.95351},
#  {'name': "Luigi's Pizzeria",
#   'review_count': 284,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6897,
#   'longitude': -73.965369},
#  {'name': 'Unregular Pizza',
#   'review_count': 216,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.73368221456629,
#   'longitude': -73.98959979038267},
#  {'name': 'East Village Pizza',
#   'review_count': 501,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.728212,
#   'longitude': -73.985182},
#  {'name': 'Di Fara Pizza',
#   'review_count': 3984,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.625093,
#   'longitude': -73.961531},
#  {'name': "Patsy's Pizzeria",
#   'review_count': 618,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6818695,
#   'longitude': -73.976181},
#  {'name': 'Roebling Pizza',
#   'review_count': 136,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7084890714263,
#   'longitude': -73.9610940711639},
#  {'name': 'Razza',
#   'review_count': 1217,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7177776,
#   'longitude': -74.0442612},
#  {'name': 'Il Porto',
#   'review_count': 388,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6974427,
#   'longitude': -73.9675197},
#  {'name': 'Da Andrea',
#   'review_count': 1955,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.736218,
#   'longitude': -73.99597},
#  {'name': "MAMA'S TOO!",
#   'review_count': 656,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.80084,
#   'longitude': -73.96766},
#  {'name': 'La Nonna Krispy Krust Pizza',
#   'review_count': 75,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.717953,
#   'longitude': -73.9637027},
#  {'name': 'Koronet Pizza',
#   'review_count': 121,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.844287,
#   'longitude': -73.939259},
#  {'name': "Vinnie's Pizzeria",
#   'review_count': 748,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7189,
#   'longitude': -73.956843},
#  {'name': 'Champion Pizza',
#   'review_count': 422,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7215270996094,
#   'longitude': -73.9970855712891},
#  {'name': 'Pizza Barn',
#   'review_count': 506,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.92033366683442,
#   'longitude': -73.86751644723435},
#  {'name': 'Ribalta Pizza',
#   'review_count': 760,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7334346,
#   'longitude': -73.9916923},
#  {'name': 'Paesano of Mulberry Street',
#   'review_count': 1387,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.718554,
#   'longitude': -73.997447},
#  {'name': 'Il Mattone',
#   'review_count': 112,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.720799,
#   'longitude': -74.0091255},
#  {'name': 'Best Pizza',
#   'review_count': 712,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7156,
#   'longitude': -73.95352},
#  {'name': 'Williamsburg Pizza',
#   'review_count': 278,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.71822,
#   'longitude': -73.99123},
#  {'name': "Carmine's Pizzeria",
#   'review_count': 523,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.714987,
#   'longitude': -73.94414},
#  {'name': 'Barboncino Pizza & Bar',
#   'review_count': 1125,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.67206,
#   'longitude': -73.95717},
#  {'name': 'Fornino',
#   'review_count': 298,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.692930215177675,
#   'longitude': -74.00165153160219},
#  {'name': "Brooklyn's Homeslice Pizzeria",
#   'review_count': 193,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.680702,
#   'longitude': -73.967455},
#  {'name': "Dani's House of Pizza",
#   'review_count': 1178,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7089474315161,
#   'longitude': -73.83051320334309},
#  {'name': "Ignazio's",
#   'review_count': 624,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.703137,
#   'longitude': -73.993608},
#  {'name': 'Krispy Pizza ',
#   'review_count': 345,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.62236,
#   'longitude': -74.0055},
#  {'name': 'Fornino- Greenpoint',
#   'review_count': 248,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.728949,
#   'longitude': -73.953999},
#  {'name': "Luigi's Pizza",
#   'review_count': 482,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.66163,
#   'longitude': -73.99334},
#  {'name': "Freddie & Pepper's",
#   'review_count': 520,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.779999,
#   'longitude': -73.980301},
#  {'name': 'Motorino',
#   'review_count': 1125,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73039,
#   'longitude': -73.98381},
#  {'name': 'New Park Pizza',
#   'review_count': 1039,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6627403949909,
#   'longitude': -73.8403776268684},
#  {'name': 'Mahsil',
#   'review_count': 85,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7634285660493,
#   'longitude': -73.81413158435902},
#  {'name': 'Ops',
#   'review_count': 192,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70276,
#   'longitude': -73.9171},
#  {'name': "Angelo's Coal Oven Pizzeria",
#   'review_count': 1157,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.76492,
#   'longitude': -73.97794},
#  {'name': 'La Villa',
#   'review_count': 589,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6743319055498,
#   'longitude': -73.9816949398812},
#  {'name': 'SIMÒ PIZZA',
#   'review_count': 246,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7392597584612,
#   'longitude': -74.0088130692187},
#  {'name': 'Lucia Pizza',
#   'review_count': 644,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.76032,
#   'longitude': -73.82813},
#  {'name': 'IL Brigante',
#   'review_count': 498,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.707492,
#   'longitude': -74.002571},
#  {'name': 'Time Out Market New York',
#   'review_count': 493,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70342863348067,
#   'longitude': -73.99214637055226},
#  {'name': "Tony's Pizzeria of Nassau Ave",
#   'review_count': 64,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.725290886426,
#   'longitude': -73.946226015687},
#  {'name': 'Table 87 - Brooklyn Heights',
#   'review_count': 347,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.691219329834,
#   'longitude': -73.9973449707031},
#  {'name': 'Broadway Pizzeria',
#   'review_count': 130,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6933151509676,
#   'longitude': -73.9290830120444},
#  {'name': 'J & V Pizzeria',
#   'review_count': 271,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6199507795829,
#   'longitude': -73.9896828},
#  {'name': 'Sauce',
#   'review_count': 927,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7204716,
#   'longitude': -73.9893263},
#  {'name': "Vic's",
#   'review_count': 578,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72693,
#   'longitude': -73.99319},
#  {'name': "Patsy's Pizzeria",
#   'review_count': 933,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.797157,
#   'longitude': -73.93488},
#  {'name': "Patrizia's - Williamsburg",
#   'review_count': 806,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7109154314181,
#   'longitude': -73.9673637711639},
#  {'name': 'Fascati Pizza',
#   'review_count': 265,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.6985,
#   'longitude': -73.99273},
#  {'name': 'Ogliastro',
#   'review_count': 216,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.674397,
#   'longitude': -73.963448},
#  {'name': 'Saraghina Pizzeria',
#   'review_count': 1016,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6837407,
#   'longitude': -73.9353473},
#  {'name': "Joe & Pat's Pizzeria",
#   'review_count': 305,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72892,
#   'longitude': -73.98411},
#  {'name': 'Marta',
#   'review_count': 1020,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7445882,
#   'longitude': -73.9847936},
#  {'name': 'Stage Door Pizzeria',
#   'review_count': 294,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.712121,
#   'longitude': -74.009704},
#  {'name': 'Goodfellas Pizzeria of LIC',
#   'review_count': 83,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.75334,
#   'longitude': -73.93716},
#  {'name': "Emmett's",
#   'review_count': 597,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.727303,
#   'longitude': -74.00243},
#  {'name': 'Oregano',
#   'review_count': 507,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7190165,
#   'longitude': -73.9586248},
#  {'name': "Rosa's Pizza",
#   'review_count': 193,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7139499,
#   'longitude': -73.95563},
#  {'name': 'Joe G Pizza & Restaurant',
#   'review_count': 173,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.76564,
#   'longitude': -73.9830099},
#  {'name': 'Fumo - Harlem',
#   'review_count': 576,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.821427,
#   'longitude': -73.950638},
#  {'name': 'Stone Bridge Pizza & Salad',
#   'review_count': 328,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.75225,
#   'longitude': -73.98061},
#  {'name': "Tony's Pizzeria & Restaurant",
#   'review_count': 363,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.699286,
#   'longitude': -73.918724},
#  {'name': 'Levante',
#   'review_count': 335,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.74764,
#   'longitude': -73.94173},
#  {'name': 'Frank Pepe Pizzeria Napoletana',
#   'review_count': 753,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.9647045,
#   'longitude': -73.8391204},
#  {'name': 'Milkflower',
#   'review_count': 755,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7628961,
#   'longitude': -73.9207081},
#  {'name': 'BarDough',
#   'review_count': 242,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7603523698496,
#   'longitude': -73.9898819848895},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 439,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.6810107667113,
#   'longitude': -73.9771813899279},
#  {'name': "Denino's Pizzeria & Tavern",
#   'review_count': 939,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6302266718896,
#   'longitude': -74.1402754933448},
#  {'name': 'Patzeria Perfect Pizza',
#   'review_count': 1801,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.759494511551836,
#   'longitude': -73.98673451962638},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 439,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.6810107667113,
#   'longitude': -73.9771813899279},
#  {'name': "Denino's Pizzeria & Tavern",
#   'review_count': 939,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6302266718896,
#   'longitude': -74.1402754933448},
#  {'name': 'Patzeria Perfect Pizza',
#   'review_count': 1801,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.759494511551836,
#   'longitude': -73.98673451962638},
#  {'name': 'Made In New York Pizza',
#   'review_count': 522,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.783841,
#   'longitude': -73.977569},
#  {'name': 'Famous Calabria',
#   'review_count': 99,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.711942,
#   'longitude': -73.999349},
#  {'name': "Alphonso's Pizzeria & Trattoria",
#   'review_count': 155,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7143,
#   'longitude': -73.98172},
#  {'name': 'Santa Panza',
#   'review_count': 229,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6947,
#   'longitude': -73.93068},
#  {'name': 'La Lanterna Di Vittorio',
#   'review_count': 1650,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73069,
#   'longitude': -74.00015},
#  {'name': 'Speedy Romeo',
#   'review_count': 679,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6875154792236,
#   'longitude': -73.959874469611},
#  {'name': 'Sottocasa Pizzeria - Harlem',
#   'review_count': 337,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.8055499,
#   'longitude': -73.94746},
#  {'name': 'Lions & Tigers & Squares Detroit Pizza',
#   'review_count': 544,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.74506,
#   'longitude': -73.99834},
#  {'name': "Arturo's",
#   'review_count': 776,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7273563342024,
#   'longitude': -74.0004944801331},
#  {'name': 'Little Italy Pizza',
#   'review_count': 603,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.756482,
#   'longitude': -73.981484},
#  {'name': 'Lexington Pizza Parlour',
#   'review_count': 262,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.789283,
#   'longitude': -73.9487429},
#  {'name': '&pizza - Astor Place',
#   'review_count': 217,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72981093692917,
#   'longitude': -73.9926904},
#  {'name': 'Trapizzino',
#   'review_count': 301,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72043,
#   'longitude': -73.98894},
#  {'name': "Scott's Pizza Tours",
#   'review_count': 371,
#   'rating': 5.0,
#   'price': '$$',
#   'latitude': 40.750244140625,
#   'longitude': -73.9970245361328},
#  {'name': "Patrizia's Pizza and Pasta",
#   'review_count': 768,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7398415,
#   'longitude': -73.9792862},
#  {'name': "Louie's Pizza",
#   'review_count': 538,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.74600424769782,
#   'longitude': -73.88356062541311},
#  {'name': 'Piccolo Trattoria',
#   'review_count': 117,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.7591676767848,
#   'longitude': -73.9525466887989},
#  {'name': 'Osteria Morini',
#   'review_count': 1293,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7219179851303,
#   'longitude': -73.9976472073402},
#  {'name': 'Luzzos La Pizza Napoletana',
#   'review_count': 1091,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.721836749997586,
#   'longitude': -73.98329136062472},
#  {'name': "Totonno's",
#   'review_count': 844,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.578913225666966,
#   'longitude': -73.98383392883555},
#  {'name': "Ray's Pizza",
#   'review_count': 418,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.7604321973079,
#   'longitude': -73.9839891042824},
#  {'name': "Rosario's",
#   'review_count': 192,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.77479,
#   'longitude': -73.91186},
#  {'name': 'GRUPPO NYCThinCrust Pizza',
#   'review_count': 277,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72474,
#   'longitude': -73.98161},
#  {'name': 'Jentana Pizza Restaurant',
#   'review_count': 77,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6375122070312,
#   'longitude': -73.9994735717773},
#  {'name': "Luzzo's BK",
#   'review_count': 216,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.690706,
#   'longitude': -73.9952269},
#  {'name': 'Motorino Pizzeria Napoletana',
#   'review_count': 267,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7104799,
#   'longitude': -73.96351},
#  {'name': 'Sotto 13',
#   'review_count': 1043,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7372,
#   'longitude': -73.99919},
#  {'name': 'Leuca',
#   'review_count': 427,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.722121,
#   'longitude': -73.956678},
#  {'name': 'Retro Pizza Cafe',
#   'review_count': 209,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7584403193969,
#   'longitude': -73.917931338696},
#  {'name': 'Circa Brewing',
#   'review_count': 413,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.69165,
#   'longitude': -73.98603},
#  {'name': 'Artistic Pizza',
#   'review_count': 121,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.73068,
#   'longitude': -74.00042},
#  {'name': 'Kesté Pizza & Vino',
#   'review_count': 1831,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70937768719562,
#   'longitude': -74.00483341921786},
#  {'name': 'Loring Place',
#   'review_count': 547,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.73293764919451,
#   'longitude': -73.99758608256435},
#  {'name': 'Emmy Squared Pizza - East Village ',
#   'review_count': 365,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72598,
#   'longitude': -73.98672},
#  {'name': 'House of Pizza & Calzones',
#   'review_count': 174,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.683944,
#   'longitude': -74.00225},
#  {'name': 'Motorino Pizzeria Napoletana',
#   'review_count': 267,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7104799,
#   'longitude': -73.96351},
#  {'name': 'Sotto 13',
#   'review_count': 1043,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7372,
#   'longitude': -73.99919},
#  {'name': 'Leuca',
#   'review_count': 427,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.722121,
#   'longitude': -73.956678},
#  {'name': 'Retro Pizza Cafe',
#   'review_count': 209,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7584403193969,
#   'longitude': -73.917931338696},
#  {'name': "Pop's Pizzas",
#   'review_count': 154,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.767086,
#   'longitude': -73.983033},
#  {'name': 'Circa Brewing',
#   'review_count': 413,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.69165,
#   'longitude': -73.98603},
#  {'name': 'Artistic Pizza',
#   'review_count': 121,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.73068,
#   'longitude': -74.00042},
#  {'name': 'Kesté Pizza & Vino',
#   'review_count': 1831,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70937768719562,
#   'longitude': -74.00483341921786},
#  {'name': 'Loring Place',
#   'review_count': 547,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.73293764919451,
#   'longitude': -73.99758608256435},
#  {'name': 'Emmy Squared Pizza - East Village ',
#   'review_count': 365,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72598,
#   'longitude': -73.98672},
#  {'name': "Antonio's Pizzeria & Restaurant",
#   'review_count': 270,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.67715,
#   'longitude': -73.97274},
#  {'name': 'House of Pizza & Calzones',
#   'review_count': 174,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.683944,
#   'longitude': -74.00225},
#  {'name': 'Seppe Pizza Bar',
#   'review_count': 167,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6289619070028,
#   'longitude': -74.0742813552762},
#  {'name': 'K Pizza',
#   'review_count': 68,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.842018,
#   'longitude': -74.000809},
#  {'name': "Philomena's",
#   'review_count': 168,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.743264,
#   'longitude': -73.922928},
#  {'name': "Grimaldi's",
#   'review_count': 833,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7412157,
#   'longitude': -73.9938935},
#  {'name': 'Margherita NYC',
#   'review_count': 314,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7189865112305,
#   'longitude': -73.9969329833984},
#  {'name': "Natoli's",
#   'review_count': 333,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.79508,
#   'longitude': -74.06316},
#  {'name': 'Prince Pizza',
#   'review_count': 48,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7238165289164,
#   'longitude': -73.9504531770945},
#  {'name': 'Rocco Pizza',
#   'review_count': 207,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.69224,
#   'longitude': -73.945849},
#  {'name': 'Lo Duca Pizza',
#   'review_count': 152,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6349400235262,
#   'longitude': -73.9625812061059},
#  {'name': 'Rosemary’s',
#   'review_count': 226,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.735097,
#   'longitude': -73.979074},
#  {'name': "Ciccio's Pizza",
#   'review_count': 129,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.596872,
#   'longitude': -73.976309},
#  {'name': "Famous Original Ray's Pizza",
#   'review_count': 443,
#   'rating': 2.5,
#   'price': '$',
#   'latitude': 40.7632745057344,
#   'longitude': -73.9815969765186},
#  {'name': 'PizzArte',
#   'review_count': 1280,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7629335072372,
#   'longitude': -73.9776668697596},
#  {'name': 'VEZZO NYCThinCrust Pizza',
#   'review_count': 1389,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.744435447210506,
#   'longitude': -73.9814189},
#  {'name': 'POSTO NYCThinCrust Pizza',
#   'review_count': 660,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73483,
#   'longitude': -73.98282},
#  {'name': "Roberta's Pizza",
#   'review_count': 249,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.754393,
#   'longitude': -73.976103},
#  {'name': 'Two Boots Pizza - West Village',
#   'review_count': 69,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.73314309005766,
#   'longitude': -74.0027964258894},
#  {'name': 'Osteria Brooklyn',
#   'review_count': 205,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.693154,
#   'longitude': -73.967177},
#  {'name': 'B Side Pizza & Wine Bar',
#   'review_count': 1290,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.76388,
#   'longitude': -73.98821},
#  {'name': "Santillo's Brick Oven Pizza",
#   'review_count': 514,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.64898,
#   'longitude': -74.21664536653269},
#  {'name': 'Baci & Abbracci',
#   'review_count': 348,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7139015197754,
#   'longitude': -73.96044921875},
#  {'name': 'DaVinci Pizzeria',
#   'review_count': 158,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.618881,
#   'longitude': -73.990798},
#  {'name': 'Harlem Pizza Co',
#   'review_count': 221,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.8029069,
#   'longitude': -73.9510825},
#  {'name': 'Pizzette',
#   'review_count': 73,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70858,
#   'longitude': -73.94357},
#  {'name': 'Salvatores of Soho',
#   'review_count': 339,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.8875232,
#   'longitude': -73.90704},
#  {'name': "Mark's Red Hook Pizza",
#   'review_count': 82,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6788288,
#   'longitude': -74.0113214},
#  {'name': 'Harlem Pizza Co',
#   'review_count': 221,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.8029069,
#   'longitude': -73.9510825},
#  {'name': 'Pizzette',
#   'review_count': 73,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70858,
#   'longitude': -73.94357},
#  {'name': 'Salvatores of Soho',
#   'review_count': 339,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.8875232,
#   'longitude': -73.90704},
#  {'name': "Mark's Red Hook Pizza",
#   'review_count': 82,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6788288,
#   'longitude': -74.0113214},
#  {'name': 'Numero 28 Ristorante Pizzeria Bar',
#   'review_count': 579,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73041,
#   'longitude': -73.98595},
#  {'name': "Nino's 46",
#   'review_count': 1391,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7569046125342,
#   'longitude': -73.980516},
#  {'name': "Mike's Pizza",
#   'review_count': 148,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.75214,
#   'longitude': -73.934339},
#  {'name': 'Carnegie Pizza',
#   'review_count': 226,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.75534,
#   'longitude': -73.98792},
#  {'name': 'Montesacro Pinseria Brooklyn',
#   'review_count': 243,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.71338,
#   'longitude': -73.95136},
#  {'name': 'Adoro Lei',
#   'review_count': 359,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.725612,
#   'longitude': -74.007916},
#  {'name': 'Leo',
#   'review_count': 96,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7125608,
#   'longitude': -73.9567886},
#  {'name': 'Underground Pizza',
#   'review_count': 334,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.70499,
#   'longitude': -74.00961},
#  {'name': 'Panzerotti Bites',
#   'review_count': 168,
#   'rating': 5.0,
#   'price': '$$',
#   'latitude': 40.683715,
#   'longitude': -73.99227},
#  {'name': 'Krispy Pizza',
#   'review_count': 248,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.713375,
#   'longitude': -74.035044},
#  {'name': "John's of Times Square",
#   'review_count': 2446,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75823,
#   'longitude': -73.98836},
#  {'name': 'Union Pizza Works',
#   'review_count': 292,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7073067,
#   'longitude': -73.922154},
#  {'name': 'Brunetti Pizza',
#   'review_count': 350,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73829,
#   'longitude': -74.0054},
#  {'name': 'Casa Theodoro',
#   'review_count': 138,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75693,
#   'longitude': -73.906747},
#  {'name': "Saluggi's East",
#   'review_count': 141,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.715948062187,
#   'longitude': -73.9873785183775},
#  {'name': '&pizza - Wall St',
#   'review_count': 144,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7057647,
#   'longitude': -74.0085474},
#  {'name': 'BRADO NYCThinCrust Pizza',
#   'review_count': 164,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6905570310882,
#   'longitude': -73.99494681265617},
#  {'name': 'La Villa Pizzeria & Restaurant',
#   'review_count': 328,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.61692,
#   'longitude': -73.9098},
#  {'name': 'Marlow Bistro',
#   'review_count': 354,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.8028109023738,
#   'longitude': -73.9641991912535},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 308,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.70638449968762,
#   'longitude': -73.92288771165168},
#  {'name': "Sofia's Pizza",
#   'review_count': 276,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.67751,
#   'longitude': -73.82586},
#  {'name': "Sal & Carmine's Pizza",
#   'review_count': 399,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7983115,
#   'longitude': -73.9694405},
#  {'name': 'Da Gennaro',
#   'review_count': 1269,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.71832,
#   'longitude': -73.99794},
#  {'name': 'Famous Famiglia Pizzeria',
#   'review_count': 101,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.778337,
#   'longitude': -73.956623},
#  {'name': "Julie's Pizzeria & Restaurant",
#   'review_count': 63,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.704239,
#   'longitude': -73.9072084},
#  {'name': 'Two Boots East Village',
#   'review_count': 415,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.723658440431656,
#   'longitude': -73.98503439649534},
#  {'name': 'Pizzeria La Rosa',
#   'review_count': 228,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.901821,
#   'longitude': -73.790987},
#  {'name': 'Upside Pizza',
#   'review_count': 54,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.75157,
#   'longitude': -73.98059},
#  {'name': 'Inatteso Pizzabar',
#   'review_count': 350,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7056571,
#   'longitude': -74.0172056},
#  {'name': 'Margherita Pizza',
#   'review_count': 362,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7045845329735,
#   'longitude': -73.7967360578922},
#  {'name': 'Spunto',
#   'review_count': 467,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7297584,
#   'longitude': -74.0046303},
#  {'name': 'Sotto Le Stelle',
#   'review_count': 365,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.743656,
#   'longitude': -73.9201782},
#  {'name': 'Toskana Pizzeria Restaurant',
#   'review_count': 324,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.767877793965,
#   'longitude': -73.7381651804604},
#  {'name': 'Don Angie',
#   'review_count': 720,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.73778,
#   'longitude': -74.00197},
#  {'name': 'Marabella Pizza',
#   'review_count': 147,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7402335928167,
#   'longitude': -73.9238661770474},
#  {'name': 'Corner Slice',
#   'review_count': 156,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7623377,
#   'longitude': -73.9967579},
#  {'name': 'Champion Pizza',
#   'review_count': 162,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.719742,
#   'longitude': -73.9872791},
#  {'name': 'Aurora',
#   'review_count': 813,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.715621,
#   'longitude': -73.964757},
#  {'name': 'Boardwalk Pizza',
#   'review_count': 201,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.59074487294477,
#   'longitude': -73.79702526442006},
#  {'name': "Salvatore's Coal Oven Pizzeria",
#   'review_count': 276,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.8417046944816,
#   'longitude': -73.7070563506088},
#  {'name': 'Champion Pizza',
#   'review_count': 97,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.73592407559118,
#   'longitude': -73.99391475241151},
#  {'name': "Ovest Pizzoteca by Luzzo's",
#   'review_count': 600,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7507476806641,
#   'longitude': -74.0030212402344},
#  {'name': "Luna's Pizzeria & Restaurant",
#   'review_count': 9,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7603635173753,
#   'longitude': -74.0371671497532},
#  {'name': "J's Pizza",
#   'review_count': 144,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7398164,
#   'longitude': -73.9989453},
#  {'name': 'Mercato Tomato Pie',
#   'review_count': 354,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73486,
#   'longitude': -74.17068},
#  {'name': "Denino's Greenwich Village",
#   'review_count': 264,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7294,
#   'longitude': -74.00111},
#  {'name': 'Pizza Classica',
#   'review_count': 489,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.706858,
#   'longitude': -73.855654},
#  {'name': 'Previti Pizza',
#   'review_count': 448,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7509380299598,
#   'longitude': -73.9767879766344},
#  {'name': "Johnny's Pizzeria",
#   'review_count': 413,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.917609,
#   'longitude': -73.839425},
#  {'name': 'Pier 76',
#   'review_count': 261,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.640118,
#   'longitude': -74.0759269},
#  {'name': 'Coletta',
#   'review_count': 193,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.74094,
#   'longitude': -73.98139},
#  {'name': "Screamer's Pizzeria",
#   'review_count': 437,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7235518,
#   'longitude': -73.95065},
#  {'name': "Joe's Pizza",
#   'review_count': 10,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.85392,
#   'longitude': -73.88413},
#  {'name': "Percy's Pizza",
#   'review_count': 256,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.729076,
#   'longitude': -74.001534},
#  {'name': "Rocky's Number II",
#   'review_count': 340,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.74442,
#   'longitude': -73.9765},
#  {'name': "Freddy's Pizzeria",
#   'review_count': 105,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.788956,
#   'longitude': -73.814049},
#  {'name': 'Proto’s Pizza',
#   'review_count': 110,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.725353,
#   'longitude': -73.989746},
#  {'name': 'Original Pizza',
#   'review_count': 136,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.63781,
#   'longitude': -73.8963799},
#  {'name': 'La Casa Bella',
#   'review_count': 312,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.590666,
#   'longitude': -73.991456},
#  {'name': 'Mia Pizza',
#   'review_count': 131,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.77907,
#   'longitude': -73.91439},
#  {'name': "Arturo's Pizza",
#   'review_count': 161,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.77528,
#   'longitude': -73.94737},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 1694,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.74406421842744,
#   'longitude': -74.00655890429283},
#  {'name': "Jiannetto's Pizza Truck",
#   'review_count': 37,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.70525,
#   'longitude': -74.00675},
#  {'name': 'Clinton Square Pizza',
#   'review_count': 88,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.71395,
#   'longitude': -73.98724},
#  {'name': "Angelo's Pizza",
#   'review_count': 671,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7638169909039,
#   'longitude': -73.9827420901337},
#  {'name': "Frank's Trattoria",
#   'review_count': 177,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.73612,
#   'longitude': -73.979473},
#  {'name': 'Pier 76',
#   'review_count': 261,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.640118,
#   'longitude': -74.0759269},
#  {'name': 'Full Moon Pizzeria',
#   'review_count': 343,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.85536,
#   'longitude': -73.88758},
#  {'name': 'Coletta',
#   'review_count': 193,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.74094,
#   'longitude': -73.98139},
#  {'name': "Screamer's Pizzeria",
#   'review_count': 437,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7235518,
#   'longitude': -73.95065},
#  {'name': "Joe's Pizza",
#   'review_count': 10,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.85392,
#   'longitude': -73.88413},
#  {'name': "Percy's Pizza",
#   'review_count': 256,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.729076,
#   'longitude': -74.001534},
#  {'name': "Rocky's Number II",
#   'review_count': 340,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.74442,
#   'longitude': -73.9765},
#  {'name': "Freddy's Pizzeria",
#   'review_count': 105,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.788956,
#   'longitude': -73.814049},
#  {'name': 'Proto’s Pizza',
#   'review_count': 110,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.725353,
#   'longitude': -73.989746},
#  {'name': 'Original Pizza',
#   'review_count': 136,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.63781,
#   'longitude': -73.8963799},
#  {'name': 'La Casa Bella',
#   'review_count': 312,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.590666,
#   'longitude': -73.991456},
#  {'name': 'Mia Pizza',
#   'review_count': 131,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.77907,
#   'longitude': -73.91439},
#  {'name': "Alberto's Restaurant & Pizzeria",
#   'review_count': 68,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.797094,
#   'longitude': -74.1482778},
#  {'name': "Arturo's Pizza",
#   'review_count': 161,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.77528,
#   'longitude': -73.94737},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 1694,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.74406421842744,
#   'longitude': -74.00655890429283},
#  {'name': "Jiannetto's Pizza Truck",
#   'review_count': 37,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.70525,
#   'longitude': -74.00675},
#  {'name': 'Clinton Square Pizza',
#   'review_count': 88,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.71395,
#   'longitude': -73.98724},
#  {'name': 'Fumo- Upper West Side',
#   'review_count': 227,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.80285617298625,
#   'longitude': -73.968119},
#  {'name': "Angelo's Pizza",
#   'review_count': 671,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7638169909039,
#   'longitude': -73.9827420901337},
#  {'name': 'ZuriLee Restaurant',
#   'review_count': 312,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.654521,
#   'longitude': -73.959443},
#  {'name': 'Motorino',
#   'review_count': 288,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7855672,
#   'longitude': -73.9730817},
#  {'name': "Famous Ben's Pizza",
#   'review_count': 393,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.7249388,
#   'longitude': -74.002451},
#  {'name': 'Bklyn Pizza',
#   'review_count': 173,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.68903,
#   'longitude': -73.92408},
#  {'name': 'Roma Pizza',
#   'review_count': 382,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.77843,
#   'longitude': -73.94863},
#  {'name': 'Don Filippo Restaurant',
#   'review_count': 197,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.774562,
#   'longitude': -73.958892},
#  {'name': "Rocco's Pizzeria",
#   'review_count': 112,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.62692170776024,
#   'longitude': -74.023899},
#  {'name': "Napoli's Pizza",
#   'review_count': 193,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73937,
#   'longitude': -74.03483},
#  {'name': "Joe's Pizza",
#   'review_count': 91,
#   'rating': 2.5,
#   'price': '$',
#   'latitude': 40.7439080906573,
#   'longitude': -73.9997112751007},
#  {'name': "Joe & Pat's Pizzeria",
#   'review_count': 477,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.61281,
#   'longitude': -74.12198},
#  {'name': "Antonio's Trattoria",
#   'review_count': 1034,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.854131,
#   'longitude': -73.886601},
#  {'name': '2 Bros Pizza',
#   'review_count': 629,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.72866,
#   'longitude': -73.988487},
#  {'name': 'Bella Pizza',
#   'review_count': 94,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.86291,
#   'longitude': -73.90197},
#  {'name': 'Tufino Pizzeria Napoletana',
#   'review_count': 462,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.773986,
#   'longitude': -73.908126},
#  {'name': 'Parm',
#   'review_count': 423,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.714473491420726,
#   'longitude': -74.01609333303082},
#  {'name': 'Mama Mia 44 SW',
#   'review_count': 839,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.759761,
#   'longitude': -73.992065},
#  {'name': 'armandos Pizza',
#   'review_count': 75,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6835403,
#   'longitude': -73.9111862},
#  {'name': 'Emily',
#   'review_count': 917,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.68351,
#   'longitude': -73.96643},
#  {'name': 'Venezia Pizzeria',
#   'review_count': 55,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.85993,
#   'longitude': -73.85515},
#  {'name': "Giovanni's Pizza Restaurant",
#   'review_count': 23,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.741315,
#   'longitude': -73.917955},
#  {'name': 'Royal Pizzeria Restaurant',
#   'review_count': 9,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.655174,
#   'longitude': -73.887446},
#  {'name': 'Little Italy Pizza',
#   'review_count': 133,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7347831726074,
#   'longitude': -73.9922409057617},
#  {'name': 'Barosa',
#   'review_count': 417,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.726197,
#   'longitude': -73.869795},
#  {'name': 'Original Pizza',
#   'review_count': 215,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.6203982490085,
#   'longitude': -73.9172416847543},
#  {'name': 'A-1 Pizza Shop',
#   'review_count': 36,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.715061,
#   'longitude': -73.982355},
#  {'name': '2 Bros Pizza',
#   'review_count': 458,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.75681,
#   'longitude': -73.980238},
#  {'name': 'VIPizza',
#   'review_count': 348,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7612782716751,
#   'longitude': -73.7699277698994},
#  {'name': 'Hatchets & Hops - Brooklyn Axe Throwing',
#   'review_count': 24,
#   'rating': 5.0,
#   'price': '$$$',
#   'latitude': 40.7212414,
#   'longitude': -73.95767370825116},
#  {'name': 'Love & Dough',
#   'review_count': 255,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.702950557308085,
#   'longitude': -73.98748593042708},
#  {'name': "Rosa's Pizza",
#   'review_count': 452,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.72697,
#   'longitude': -73.89564},
#  {'name': 'Brooklyn Pizza Market',
#   'review_count': 116,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.68273,
#   'longitude': -73.99305},
#  {'name': 'Divino Pizzeria Restaurant',
#   'review_count': 188,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.650639,
#   'longitude': -73.83808},
#  {'name': 'Oath Pizza - New York',
#   'review_count': 264,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7664835,
#   'longitude': -73.9633564},
#  {'name': 'Swift',
#   'review_count': 377,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.727309,
#   'longitude': -73.992387},
#  {'name': "Alfie's Pizza",
#   'review_count': 182,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.69983,
#   'longitude': -73.83291},
#  {'name': 'Pizza Wagon',
#   'review_count': 314,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.62129,
#   'longitude': -74.02659},
#  {'name': 'Lunetta Pizza & Restaurant',
#   'review_count': 177,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.736942,
#   'longitude': -73.984176},
#  {'name': 'La Villa Pizzeria',
#   'review_count': 157,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6112945152771,
#   'longitude': -74.0082534402609},
#  {'name': "Carmine's Italian Restaurant - Times Square",
#   'review_count': 4542,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75749848725768,
#   'longitude': -73.98665333142026},
#  {'name': "Saba's Pizza",
#   'review_count': 121,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.78329,
#   'longitude': -73.978},
#  {'name': 'Patsy’s Pizzeria',
#   'review_count': 464,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.76177,
#   'longitude': -73.96575},
#  {'name': 'Lenny and Johns Pizzeria',
#   'review_count': 254,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.6199963,
#   'longitude': -73.9342463},
#  {'name': 'Donna Margherita',
#   'review_count': 182,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.76652,
#   'longitude': -73.9598},
#  {'name': 'Rosa Pizzeria of Harlem',
#   'review_count': 25,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.80638,
#   'longitude': -73.95371},
#  {'name': "Lazzara's Pizza",
#   'review_count': 347,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.754057,
#   'longitude': -73.989497},
#  {'name': "Patsy's Pizzeria",
#   'review_count': 320,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.750427,
#   'longitude': -73.972129},
#  {'name': 'Villa Milano ',
#   'review_count': 235,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.795065,
#   'longitude': -73.698539},
#  {'name': "Rosella's Pizzeria",
#   'review_count': 273,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.710117,
#   'longitude': -74.005661},
#  {'name': "Jimmy's Pizzeria",
#   'review_count': 61,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.6913995614207,
#   'longitude': -73.9090716926598},
#  {'name': 'Pizza Secret',
#   'review_count': 254,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6808,
#   'longitude': -73.97764},
#  {'name': 'Tino’s Artisan Pizza',
#   'review_count': 118,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.71416668884163,
#   'longitude': -74.03979259017832},
#  {'name': 'Campania Coal Fired Pizza',
#   'review_count': 692,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6136093139648,
#   'longitude': -74.033332824707},
#  {'name': 'Rooftop Reds',
#   'review_count': 173,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7025733903159,
#   'longitude': -73.9698984748688},
#  {'name': 'Baciccia Pizza e Cucina',
#   'review_count': 149,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.663816,
#   'longitude': -73.98448},
#  {'name': "Patsy's Pizzeria",
#   'review_count': 581,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7785204,
#   'longitude': -73.9769718},
#  {'name': 'San Matteo Pizza and Espresso Bar',
#   'review_count': 560,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7804,
#   'longitude': -73.95012},
#  {'name': "Sal's Pizzeria",
#   'review_count': 203,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.71322,
#   'longitude': -73.94911},
#  {'name': "Renato's Pizza Masters",
#   'review_count': 473,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7442813,
#   'longitude': -74.0503861},
#  {'name': "Harry's Italian",
#   'review_count': 279,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7153762863468,
#   'longitude': -74.0139836332683},
#  {'name': 'Zero Otto Nove',
#   'review_count': 541,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7407551035259,
#   'longitude': -73.9914887388588},
#  {'name': "Danny's Pizzeria & Cafe",
#   'review_count': 192,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.70787,
#   'longitude': -73.93971},
#  {'name': 'Pasta by Hudson',
#   'review_count': 113,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7427486,
#   'longitude': -73.9969892},
#  {'name': "Giuseppina's",
#   'review_count': 352,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6603430973463,
#   'longitude': -73.9907741546631},
#  {'name': 'IL FORNO A LEGNA',
#   'review_count': 344,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6064118,
#   'longitude': -74.2743223},
#  {'name': "Vinnie's Pizzeria",
#   'review_count': 168,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.776219,
# ...
#   'longitude': -74.1255893558264},
#  {'name': "Sapori D'Italia",
#   'review_count': 51,
#   'rating': 5.0,
#   'price': '$$',
#   'latitude': 40.7756623592079,
#   'longitude': -74.6022406242452},
#  {'name': 'Brother’s Pizzeria',
#   'review_count': 280,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7398,
#   'longitude': -73.788972},
#  {'name': 'Tino’s Artisan Pizza',
#   'review_count': 59,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.76031458977054,
#   'longitude': -74.41667337483189},
#  {'name': 'On The Run Pizza',
#   'review_count': 27,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.57685,
#   'longitude': -73.98461},
#  {'name': "Dominick's Pizzeria",
#   'review_count': 88,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.90454,
#   'longitude': -74.21047},
#  {'name': 'Due Fratelli',
#   'review_count': 307,
#   'rating': 2.5,
#   'price': '$',
#   'latitude': 40.726044,
#   'longitude': -73.852393},
#  {'name': 'Tino’s Artisan Pizza',
#   'review_count': 494,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.37573,
#   'longitude': -74.612649},
#  {'name': 'Napoli Pizzeria & Restaurant',
#   'review_count': 159,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7329651024261,
#   'longitude': -73.8047229796821},
#  {'name': 'Krave It Pizza & Sandwich Joint ',
#   'review_count': 77,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.764537,
#   'longitude': -73.916935},
#  {'name': "Luigi's Pizzeria of Mineola",
#   'review_count': 213,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.74450383,
#   'longitude': -73.65620367},
#  {'name': 'Obicà Mozzarella Bar Pizza e Cucina',
#   'review_count': 510,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7400486,
#   'longitude': -73.9893018},
#  {'name': "Ferazzoli's Italian Kitchen",
#   'review_count': 280,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.836067,
#   'longitude': -74.1135663},
#  {'name': 'Johnny Pepperoni',
#   'review_count': 397,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75011,
#   'longitude': -74.02969},
#  {'name': "Brooklyn's Brick Oven Pizzeria",
#   'review_count': 438,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.90044,
#   'longitude': -74.0363},
#  {'name': '99 Cent Fresh Pizza',
#   'review_count': 310,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.754764,
#   'longitude': -73.987443},
#  {'name': 'Emmy Squared Pizza - Upper East Side',
#   'review_count': 264,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.77564,
#   'longitude': -73.9565},
#  {'name': "Whit's End",
#   'review_count': 325,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.5850368,
#   'longitude': -73.8190164},
#  {'name': 'Gotham Pizza',
#   'review_count': 139,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.777568,
#   'longitude': -73.949218},
#  {'name': 'Malatesta Trattoria',
#   'review_count': 1350,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73285,
#   'longitude': -74.00847},
#  {'name': 'Napoli Pizza & Pasta',
#   'review_count': 351,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.75718,
#   'longitude': -73.92686},
#  {'name': "Eddie D's Pizzeria",
#   'review_count': 78,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6777937,
#   'longitude': -73.7095485},
#  {'name': 'Pinos La Forchetta Pizzeria',
#   'review_count': 227,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.671257019043,
#   'longitude': -73.9775695800781},
#  {'name': "Smokey's Brick Oven Tavern",
#   'review_count': 261,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 41.21533,
#   'longitude': -74.49513},
#  {'name': 'Gnoccheria East Village',
#   'review_count': 518,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.723315,
#   'longitude': -73.983139},
#  {'name': 'Slice Pizza',
#   'review_count': 62,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.75202,
#   'longitude': -73.97376},
#  {'name': "Turiello's Pizza House & Restaurant",
#   'review_count': 155,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 41.0911199,
#   'longitude': -73.91836},
#  {'name': 'Maspeth Pizza',
#   'review_count': 71,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.72815,
#   'longitude': -73.89206},
#  {'name': 'Porto Bello',
#   'review_count': 227,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.770352,
#   'longitude': -73.904303},
#  {'name': 'Sally’s Apizza',
#   'review_count': 143,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 41.05372,
#   'longitude': -73.54162},
#  {'name': 'S. Egidio',
#   'review_count': 554,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.980227,
#   'longitude': -74.120093},
#  {'name': 'Via Caramico',
#   'review_count': 29,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7517417637889,
#   'longitude': -73.9307737084595},
#  {'name': 'Brothers Pizza',
#   'review_count': 62,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.66341,
#   'longitude': -73.99468},
#  {'name': "Catania's Pizzeria & Cafe",
#   'review_count': 37,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.853683,
#   'longitude': -73.889304},
#  {'name': 'Comet Pizzeria',
#   'review_count': 24,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.69442,
#   'longitude': -74.21642},
#  {'name': 'Locanda Verde',
#   'review_count': 1824,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7198601300801,
#   'longitude': -74.010039072422},
#  {'name': 'Damascus Bakery',
#   'review_count': 5,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70322,
#   'longitude': -73.98308},
#  {'name': 'Samaria Pizza',
#   'review_count': 73,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.765664798585,
#   'longitude': -73.930791735236},
#  {'name': 'Frankies 457 Spuntino',
#   'review_count': 897,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.677328,
#   'longitude': -73.997972},
#  {'name': 'Frankie Portugal',
#   'review_count': 87,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.74410235341,
#   'longitude': -74.00647},
#  {'name': "Katz's Delicatessen",
#   'review_count': 15008,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.722237,
#   'longitude': -73.9875259},
#  {'name': "Leo's Pizza",
#   'review_count': 68,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7566866,
#   'longitude': -73.9296278},
#  {'name': '99 Cent Fresh Pizza',
#   'review_count': 292,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7517,
#   'longitude': -73.97432},
#  {'name': 'Sfilatino Italian Gourmet',
#   'review_count': 222,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7675056,
#   'longitude': -73.9851073},
#  {'name': 'Ulivo',
#   'review_count': 373,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7447371960713,
#   'longitude': -73.9880339428782},
#  {'name': 'Roll-N-Roaster',
#   'review_count': 1357,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.5840481565596,
#   'longitude': -73.9396257952115},
#  {'name': 'Cheesy Pizza',
#   'review_count': 126,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.79716,
#   'longitude': -73.96948},
#  {'name': "Jeannie's",
#   'review_count': 23,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7662427,
#   'longitude': -73.98124349999999},
#  {'name': "Mimmo's Brick Oven Pizza and Trattoria",
#   'review_count': 200,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.551229,
#   'longitude': -74.150126},
#  {'name': "Romeo's Pizzeria",
#   'review_count': 104,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.681713,
#   'longitude': -73.83699},
#  {'name': 'Zeppola Bakery',
#   'review_count': 112,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.752672726751186,
#   'longitude': -73.9891},
#  {'name': 'Zia Maria Little Italy',
#   'review_count': 354,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7185198905011,
#   'longitude': -73.99744725889785},
#  {'name': 'Brockenzo Neapolitan Pizza',
#   'review_count': 12,
#   'rating': 5.0,
#   'price': '$$',
#   'latitude': 40.7503547668457,
#   'longitude': -73.9447784423828},
#  {'name': 'Gino S Of Kissena',
#   'review_count': 184,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.737017,
#   'longitude': -73.814383},
#  {'name': 'Delizia 92',
#   'review_count': 303,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.78152,
#   'longitude': -73.94886},
#  {'name': "Sticky's Finger Joint",
#   'review_count': 475,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.74505372839559,
#   'longitude': -73.9788811},
#  {'name': 'Centro Pizza',
#   'review_count': 64,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7717910087337,
#   'longitude': -73.9563909799841},
#  {'name': 'Ortomare Ristorante Pizzeria',
#   'review_count': 137,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.80124,
#   'longitude': -73.96161},
#  {'name': 'Yankee J-Z Pizza',
#   'review_count': 65,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.8292327076197,
#   'longitude': -73.8757006824017},
#  {'name': 'Mela Pizza House',
#   'review_count': 63,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.76765,
#   'longitude': -73.92056},
#  {'name': "Robert's Pizzeria",
#   'review_count': 98,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7408097,
#   'longitude': -74.1723118},
#  {'name': "Gino's of Middle Village Pizza",
#   'review_count': 80,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7229424,
#   'longitude': -73.8741563},
#  {'name': 'Industry Kitchen',
#   'review_count': 905,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7049434740873,
#   'longitude': -74.0048825740814},
#  {'name': 'Supper',
#   'review_count': 1475,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72290786539601,
#   'longitude': -73.98520720537888},
#  {'name': 'Little Italy Pizza',
#   'review_count': 28,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.715143,
#   'longitude': -74.008037},
#  {'name': 'The Big Red Tomato',
#   'review_count': 293,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.8395,
#   'longitude': -73.98192},
#  {'name': "Armando's Pizza",
#   'review_count': 83,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.645742,
#   'longitude': -73.9027409},
#  {'name': "Fedoroff's Roast Pork",
#   'review_count': 367,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7189526,
#   'longitude': -73.9555245},
#  {'name': 'Saint Pizza',
#   'review_count': 4,
#   'rating': 5.0,
#   'price': '$',
#   'latitude': 40.72905715251202,
#   'longitude': -73.97811846649704},
#  {'name': 'La Amistad Pizzeria & Grill',
#   'review_count': 26,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.79098,
#   'longitude': -73.94241},
#  {'name': 'Quality Italian',
#   'review_count': 1365,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7644044527436,
#   'longitude': -73.9767805051616},
#  {'name': 'Pies-n-Thighs',
#   'review_count': 3182,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.711191,
#   'longitude': -73.961424},
#  {'name': "Rizzo's Bakery",
#   'review_count': 123,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.74173,
#   'longitude': -74.052106},
#  {'name': "Gino's of Middle Village Pizza",
#   'review_count': 80,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7229424,
#   'longitude': -73.8741563},
#  {'name': 'Industry Kitchen',
#   'review_count': 905,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7049434740873,
#   'longitude': -74.0048825740814},
#  {'name': "Ferdinando's Focacceria",
#   'review_count': 216,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.68418116575449,
#   'longitude': -74.0018677711487},
#  {'name': 'Supper',
#   'review_count': 1475,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72290786539601,
#   'longitude': -73.98520720537888},
#  {'name': 'Bella Donna Pizzeria',
#   'review_count': 30,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.71339588236523,
#   'longitude': -73.91075417663387},
#  {'name': 'Carroll Place',
#   'review_count': 1266,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7287,
#   'longitude': -73.99971},
#  {'name': 'The Big Red Tomato',
#   'review_count': 293,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.8395,
#   'longitude': -73.98192},
#  {'name': "Armando's Pizza",
#   'review_count': 83,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.645742,
#   'longitude': -73.9027409},
#  {'name': "Fedoroff's Roast Pork",
#   'review_count': 367,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7189526,
#   'longitude': -73.9555245},
#  {'name': 'Saint Pizza',
#   'review_count': 4,
#   'rating': 5.0,
#   'price': '$',
#   'latitude': 40.72905715251202,
#   'longitude': -73.97811846649704},
#  {'name': 'La Amistad Pizzeria & Grill',
#   'review_count': 26,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.79098,
#   'longitude': -73.94241},
#  {'name': 'Quality Italian',
#   'review_count': 1365,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7644044527436,
#   'longitude': -73.9767805051616},
#  {'name': 'Pies-n-Thighs',
#   'review_count': 3182,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.711191,
#   'longitude': -73.961424},
#  {'name': "Rizzo's Bakery",
#   'review_count': 123,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.74173,
#   'longitude': -74.052106},
#  {'name': "Junior's Restaurant",
#   'review_count': 5736,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75754728725579,
#   'longitude': -73.98608001118411},
#  {'name': 'Dozzino',
#   'review_count': 337,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.74455,
#   'longitude': -74.03579},
#  {'name': 'Parm',
#   'review_count': 877,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.72303,
#   'longitude': -73.99567},
#  {'name': "Lenny's Pizza",
#   'review_count': 146,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.74145,
#   'longitude': -73.92022},
#  {'name': "Donato's Restaurant and Pizza",
#   'review_count': 199,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.748620275297355,
#   'longitude': -73.91300763769813},
#  {'name': 'La Gondola Pizzeria ',
#   'review_count': 224,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 41.07253930513272,
#   'longitude': -74.13805680930825},
#  {'name': 'Amuni',
#   'review_count': 66,
#   'rating': 5.0,
#   'price': '$$',
#   'latitude': 40.633001,
#   'longitude': -74.026833},
#  {'name': 'Boutros',
#   'review_count': 191,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.6901481293837,
#   'longitude': -73.9935445412993},
#  {'name': 'Da Mario Pizzeria',
#   'review_count': 69,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.8278,
#   'longitude': -74.10236},
#  {'name': 'Steve’s Tuxedo',
#   'review_count': 146,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 41.188282,
#   'longitude': -74.183514},
#  {'name': 'Armandos Pizza',
#   'review_count': 44,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.646676,
#   'longitude': -73.883467},
#  {'name': 'Phillies Pizza & Restaurant',
#   'review_count': 205,
#   'rating': 2.5,
#   'price': '$$',
#   'latitude': 40.72193,
#   'longitude': -73.8853199},
#  {'name': 'Garden Pizza',
#   'review_count': 120,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.81648,
#   'longitude': -74.00288},
#  {'name': 'The Ear Inn',
#   'review_count': 428,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.725925,
#   'longitude': -74.009489},
#  {'name': 'Una Pizza Napoletana',
#   'review_count': 156,
#   'rating': 3.5,
#   'price': '$$$',
#   'latitude': 40.72175,
#   'longitude': -73.98864},
#  {'name': 'Fresh Salt',
#   'review_count': 426,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70707,
#   'longitude': -74.00244},
#  {'name': 'Porta',
#   'review_count': 1226,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.7200699,
#   'longitude': -74.0437622},
#  {'name': "Adrian's Jersey Pizza",
#   'review_count': 241,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.846881,
#   'longitude': -74.082494},
#  {'name': "L'Amico NYC",
#   'review_count': 560,
#   'rating': 3.5,
#   'price': '$$$',
#   'latitude': 40.7469265,
#   'longitude': -73.99009231127866},
#  {'name': 'Sacco Pizza',
#   'review_count': 449,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7662658691406,
#   'longitude': -73.9872665405273},
#  {'name': 'The Marshal',
#   'review_count': 835,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.761225,
#   'longitude': -73.993968},
#  {'name': 'Taste of Tuscany',
#   'review_count': 101,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.8568353549895,
#   'longitude': -74.0434074881405},
#  {'name': 'Mama Rosa Cucina Pizzeria',
#   'review_count': 78,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.648513,
#   'longitude': -74.138297},
#  {'name': "Nick's Pizza - Forest Hills",
#   'review_count': 969,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.71797254115706,
#   'longitude': -73.84048067055303}]

# %% [markdown]
# ## Summary
#
# Nice work! In this lab, you've made multiple API calls to Yelp in order to paginate through a results set, performing some basic exploratory analysis and then creating a nice interactive map to display the results using Folium! Well done!
